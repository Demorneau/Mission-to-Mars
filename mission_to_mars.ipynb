# %% [markdown]
# # Mission to Mars

# %%
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pandas as pd

# %% [markdown]
# # NASA Mars News

# %%
news_title = requests.get('https://mars.nasa.gov/news/', timeout=3)

# %%
print(news_title.text[0:500])
# Out:
# <!DOCTYPE html>
# <html lang='en' xml:lang='en' xmlns='http://www.w3.org/1999/xhtml'>
# <head>
# <meta content='text/html; charset=utf-8' http-equiv='Content-Type'>
# <!-- Always force latest IE rendering engine or request Chrome Frame -->
# <meta content='IE=edge,chrome=1' http-equiv='X-UA-Compatible'>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0

# %%
mars_news = BeautifulSoup(news_title.text,'html.parser')

# %%
print(mars_news)
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <!-- Always force latest IE rendering engine or request Chrome Frame -->
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":151,"agent":""}</script>
# ...

# %%
mars_title = mars_news.find('div', class_='content_title').text

# %%
print(mars_title)
# Out:
# NASA's Curiosity Mars Rover Finds a Clay Cache

# %%
mars_paragraph = mars_news.find('div', class_='rollover_description_inner').text

# %%
print(mars_paragraph)
# Out:
# The rover recently drilled two samples, and both showed the highest levels of clay ever found during the mission.

# %% [markdown]
# # JPL Mars Space Image - Featured Image

# %%
featured_image_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'

# %%
executable_path = {'executable_path':"chromedriver"}

# %%
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(featured_image_url)
html= browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
marsian_pic = soup.find('img', class_= 'thumb')['src']
featured_mars_pic = 'https://www.jpl.nasa.gov' + marsian_pic
print(featured_mars_pic)
# Out:
# https://www.jpl.nasa.gov/spaceimages/images/wallpaper/PIA23284-640x350.jpg

# %% [markdown]
# # Mars Weather

# %%
# Visit the Mars Weather Twitter, and scrape the latest Mars Weather Tweet from the page.

# %%
mars_weather_url = 'https://twitter.com/marswxreport?lang=en'

# %%
tweetnews_title = requests.get(mars_weather_url)

# %%
print(tweetnews_title.text)
# Out:
# <!DOCTYPE html>
# <html lang="en" data-scribe-reduced-action-queue="true">
#   <head>
#
#
#
#
#
#
#
#     <meta charset="utf-8">
#       <script  nonce="JyDjx1soylAeC635pRuGug==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
#
#
#
#   <script id="bouncer_terminate_iframe" nonce="JyDjx1soylAeC635pRuGug==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
#   <script id="swift_action_queue" nonce="JyDjx1soylAeC635pRuGug==">
# ...

# %%
tweet_weather= BeautifulSoup(tweetnews_title.text, 'html.parser')

# %%
print(tweet_weather)
# Out:
# <!DOCTYPE html>
#
# <html data-scribe-reduced-action-queue="true" lang="en">
# <head>
# <meta charset="utf-8"/>
# <script nonce="JyDjx1soylAeC635pRuGug==">
#         !function(){window.initErrorstack||(window.initErrorstack=[]),window.onerror=function(r,i,n,o,t){r.indexOf("Script error.")>-1||window.initErrorstack.push({errorMsg:r,url:i,lineNumber:n,column:o,errorObj:t})}}();
#       </script>
# <script id="bouncer_terminate_iframe" nonce="JyDjx1soylAeC635pRuGug==">
#     if (window.top != window) {
#   window.top.postMessage({'bouncer': true, 'event': 'complete'}, '*');
# }
#   </script>
# <script id="swift_action_queue" nonce="JyDjx1soylAeC635pRuGug==">
# ...

# %%
tweetmars_weather = tweet_weather.find('p', class_='TweetTextSize TweetTextSize--normal js-tweet-text tweet-text').text

# %%
print(tweetmars_weather)
# Out:
# InSight sol 198 (2019-06-17) low -104.8ºC (-156.6ºF) high -24.7ºC (-12.4ºF)
# winds from the SSE at 4.0 m/s (8.9 mph) gusting to 15.5 m/s (34.6 mph)
# pressure at 7.60 hPapic.twitter.com/YQcWLlcAy3

# %% [markdown]
# # Mars Facts

# %%
# Visit the Mars Facts webpage (https://space-facts.com/mars/) and use Pandas to scrape the table containing facts
# about the planet including Diameter, Mass, etc.

# %%
mars_tableurl = 'https://space-facts.com/mars/'

# %%
mars_tablestring = pd.read_html(mars_tableurl)[0]
mars_df = pd.DataFrame(mars_tablestring).rename(columns={0:'Mars Facts', 1:'Dimensions'}).set_index('Mars Facts')
mars_df
# Out:
#                                          Dimensions
# Mars Facts
# Equatorial Diameter:                       6,792 km
# Polar Diameter:                            6,752 km
# Mass:                 6.42 x 10^23 kg (10.7% Earth)
# Moons:                          2 (Phobos & Deimos)
# Orbit Distance:            227,943,824 km (1.52 AU)
# Orbit Period:                  687 days (1.9 years)
# Surface Temperature:                  -153 to 20 °C
# First Record:                     2nd millennium BC
# Recorded By:                   Egyptian astronomers

# %%
mars_table = mars_df.to_html(classes = 'table')

# %%
print(mars_table)
# Out:
# <table border="1" class="dataframe table">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Dimensions</th>
#     </tr>
#     <tr>
#       <th>Mars Facts</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Equatorial Diameter:</th>
#       <td>6,792 km</td>
#     </tr>
#     <tr>
#       <th>Polar Diameter:</th>
#       <td>6,752 km</td>
#     </tr>
#     <tr>
#       <th>Mass:</th>
#       <td>6.42 x 10^23 kg (10.7% Earth)</td>
#     </tr>
#     <tr>
#       <th>Moons:</th>
#       <td>2 (Phobos &amp; Deimos)</td>
#     </tr>
#     <tr>
#       <th>Orbit Distance:</th>
#       <td>227,943,824 km (1.52 AU)</td>
#     </tr>
#     <tr>
#       <th>Orbit Period:</th>
#       <td>687 days (1.9 years)</td>
#     </tr>
#     <tr>
#       <th>Surface Temperature:</th>
#       <td>-153 to 20 °C</td>
#     </tr>
#     <tr>
#       <th>First Record:</th>
#       <td>2nd millennium BC</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # Mars Hemispheres

# %%
# Visit the USGS Astrogeology site at https://astrogeology.usgs.gov/search/results?=hemisphere+enhanced&k1=target&v1=Mars
# to obtain high resolution images for each of Mar's hemispheres.

# %%
mars_hemisphere_imgurl = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars'

# %%
executable_path = {'executable_path':"chromedriver"}

# %%
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(mars_hemisphere_imgurl)
html= browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
hemisphere_pic = soup.find('img', class_= 'thumb')['src']
hemisphere_mars_pic = 'https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars' + hemisphere_pic
print(hemisphere_mars_pic)
# Out:
# https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars/cache/images/dfaf3849e74bf973b59eb50dab52b583_cerberus_enhanced.tif_thumb.png

# %%
title = soup.find_all('h3')
print(title)
# Out:
# [<h3>Cerberus Hemisphere Enhanced</h3>, <h3>Schiaparelli Hemisphere Enhanced</h3>, <h3>Syrtis Major Hemisphere Enhanced</h3>, <h3>Valles Marineris Hemisphere Enhanced</h3>]

# %%
mars_hemisphere_img_url = []
#pic_hemisphere_dict = {'title photo':[], 'img_url':[]}
for pic in range(4):
    browser.find_by_tag('h3')[pic].click()
    html= browser.html
    soup = BeautifulSoup(html,'html.parser')
    title = soup.find('h2', class_='title').text
    title = t.replace('Enhanced','')
    pic_partial_url = soup.find('img',class_='wide-image')['src']
    pic_url = 'https://astrogeology.usgs.gov' + pic_partial_url
    pic_hemisphere_dict = {'title photo': title, 'img_url':pic_url}
    mars_hemisphere_img_url.append(pic_hemisphere_dict)
    browser.back()
print(mars_hemisphere_img_url)
# Out:
# [{'title photo': 'Cerberus Hemisphere ', 'img_url': 'https://astrogeology.usgs.gov/cache/images/cfa62af2557222a02478f1fcd781d445_cerberus_enhanced.tif_full.jpg'}, {'title photo': 'Cerberus Hemisphere ', 'img_url': 'https://astrogeology.usgs.gov/cache/images/3cdd1cbf5e0813bba925c9030d13b62e_schiaparelli_enhanced.tif_full.jpg'}, {'title photo': 'Cerberus Hemisphere ', 'img_url': 'https://astrogeology.usgs.gov/cache/images/ae209b4e408bb6c3e67b6af38168cf28_syrtis_major_enhanced.tif_full.jpg'}, {'title photo': 'Cerberus Hemisphere ', 'img_url': 'https://astrogeology.usgs.gov/cache/images/7cf2da4bf549ed01c17f206327be4db7_valles_marineris_enhanced.tif_full.jpg'}]
